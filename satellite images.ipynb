# %%
import pandas as pd
import numpy as np

# %%
# !pip install sentinelsat

# %%
# !pip install geopandas
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\Mfund\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mfund\\AppData\\Local\\Temp\\pip-install-6ftnmj24\\fiona_01bce67832904ca3883fb6fabe009b91\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mfund\\AppData\\Local\\Temp\\pip-install-6ftnmj24\\fiona_01bce67832904ca3883fb6fabe009b91\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\Mfund\AppData\Local\Temp\pip-pip-egg-info-b6v3o5k6'
#          cwd: C:\Users\Mfund\AppData\Local\Temp\pip-install-6ftnmj24\fiona_01bce67832904ca3883fb6fabe009b91\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
# ...

# %%
data = pd.read_csv('C:/Users/Mfund/Downloads/Hons 2021/NDEV842/NReserve/')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-4-480eb00f0df0> in <module>
# ----> 1 data = pd.read_csv('C:/Users/Mfund/Downloads/Hons 2021/NDEV842/NReserve/')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
from sentinelsat import SentinelAPI

# %%
user = 'mfundo'
password ='970224Mfundo'
api = SentinelAPI(user,password, )
